# %%
import pandas

# %%
import numpy as np
import pandas as pd
dataset = pd.read_excel("C:\\Users\\Hikari Reiziq\\ProjectStatProbTugasCoding\\Coding-Task-1-A-046-061-079-123\\Dataset.xlsx")
dataset = pandas.read_excel("Dataset.xlsx")

# %%
dataset #Tabel Distribusi Frekuensi
# Out:
#      Tanggal  Curah Hujan (mm)  Penjualan A (pcs)  Penjualan B (pcs)
# 0          1               1.4                  0                507
# 1          2               1.2                 27                 61
# 2          3              15.2                458                367
# 3          4              13.4                 20                 21
# 4          5               7.7                  7                  0
# ..       ...               ...                ...                ...
# 116        4               2.2                430                421
# 117        5               0.5                208                 24
# 118        6              33.4                200                189
# 119        7               0.0                  0                324
# 120        8               0.0                143                315
#
# [121 rows x 4 columns]

# %%
# Convert the 'Penjualan A (pcs)' column to numeric, coercing errors into NaN
penjualan_A = pd.to_numeric(dataset['Penjualan A (pcs)'], errors='coerce')

# Drop NaN values from the 'Penjualan A (pcs)' column
penjualan_A = penjualan_A.dropna()

# Assuming you meant to work with a 'Penjualan B (pcs)' column
penjualan_B = pd.to_numeric(dataset['Penjualan B (pcs)'], errors='coerce')
penjualan_B = penjualan_B.dropna()

# %%
penjualan_B = pd.to_numeric(dataset['Penjualan B (pcs)'], errors='coerce')
penjualan_B = penjualan_B.dropna()

# %%
import matplotlib.pyplot as plt  # untuk visualisasi data

# Asumsi 'dataset' sudah didefinisikan sebelumnya dan berisi kolom 'Penjualan A (pcs)' dan 'Penjualan B (pcs)'
penjualan_A = dataset['Penjualan A (pcs)']
penjualan_B = dataset['Penjualan B (pcs)']

def calc_mean(penjualan_A, penjualan_B):
    # Hitung mean masing-masing variabel
    mean_A = sum(penjualan_A) / len(penjualan_A)
    mean_B = sum(penjualan_B) / len(penjualan_B)
    
    # Tampilkan hasil
    print(f"Mean Penjualan A: {mean_A}")
    print(f"Mean Penjualan B: {mean_B}")
    
    # Kembalikan hasil jika diperlukan
    return mean_A, mean_B

# Panggil fungsi calc_mean dengan dua variabel
mean_A, mean_B = calc_mean(penjualan_A, penjualan_B)

# Visualisasi Data
plt.figure(figsize=(10, 6))

# Plot distribusi Penjualan A
plt.subplot(1, 2, 1)  # 1 baris, 2 kolom, plot 1
plt.hist(penjualan_A, bins=10, color='blue', alpha=0.7)
plt.axvline(mean_A, color='red', linestyle='dashed', linewidth=1)
plt.title('Distribusi Penjualan A')
plt.xlabel('Penjualan A (pcs)')
plt.ylabel('Frekuensi')
plt.legend([f'Mean: {mean_A:.2f}'])

# Plot distribusi Penjualan B
plt.subplot(1, 2, 2)  # 1 baris, 2 kolom, plot 2
plt.hist(penjualan_B, bins=10, color='green', alpha=0.7)
plt.axvline(mean_B, color='red', linestyle='dashed', linewidth=1)
plt.title('Distribusi Penjualan B')
plt.xlabel('Penjualan B (pcs)')
plt.ylabel('Frekuensi')
plt.legend([f'Mean: {mean_B:.2f}'])

# Tampilkan visualisasi
plt.tight_layout()
plt.show()
# Out:
# Mean Penjualan A: 131.83471074380165
# Mean Penjualan B: 205.54545454545453

# %%
import matplotlib.pyplot as plt

def calc_median(data):
    sorted_data = sorted(data)
    n = len(sorted_data)
    index_tengah = n // 2  # Pembagian bulat (floor division)

    # Jika jumlah data genap, hitung rata-rata dari dua nilai tengah
    if n % 2 == 0:
        median1 = sorted_data[index_tengah]
        median2 = sorted_data[index_tengah - 1]
        median_value = (median1 + median2) / 2
    # Jika jumlah data ganjil, ambil nilai tengah
    else:
        median_value = sorted_data[index_tengah]
    
    print(f"Median: {median_value}")
    return median_value

# Asumsikan mean_A dan mean_B sudah dihitung sebelumnya
mean_A = sum(penjualan_A) / len(penjualan_A)  # Contoh hitung mean
mean_B = sum(penjualan_B) / len(penjualan_B)  # Contoh hitung mean

# Panggil fungsi calc_median untuk kedua dataset
median_A = calc_median(penjualan_A)
median_B = calc_median(penjualan_B)

# Visualisasi Data dengan Median
plt.figure(figsize=(10, 6))

# Plot distribusi Penjualan A dengan garis Mean dan Median
plt.subplot(1, 2, 1)
plt.hist(penjualan_A, bins=10, color='blue', alpha=0.7)
plt.axvline(mean_A, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {mean_A:.2f}')
plt.axvline(median_A, color='green', linestyle='dotted', linewidth=1, label=f'Median: {median_A:.2f}')
plt.title('Distribusi Penjualan A')
plt.xlabel('Penjualan A (pcs)')
plt.ylabel('Frekuensi')
plt.legend()

# Plot distribusi Penjualan B dengan garis Mean dan Median
plt.subplot(1, 2, 2)
plt.hist(penjualan_B, bins=10, color='green', alpha=0.7)
plt.axvline(mean_B, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {mean_B:.2f}')
plt.axvline(median_B, color='green', linestyle='dotted', linewidth=1, label=f'Median: {median_B:.2f}')
plt.title('Distribusi Penjualan B')
plt.xlabel('Penjualan B (pcs)')
plt.ylabel('Frekuensi')
plt.legend()

# Tampilkan visualisasi
plt.tight_layout()
plt.show()
# Out:
# Median: 52
# Median: 157

# %%
from collections import Counter

def calc_modus(data):
    counter = Counter(data)
    mode_data = dict(counter)  # Ubah ke tipe data dictionary
    max_counter = max(list(counter.values()))  # Cari frekuensi tertinggi
    mode_value = []
    
    # Cari nilai yang memiliki frekuensi paling tinggi
    for k, v in mode_data.items():
        if v == max_counter:
            mode_value.append(k)
    
    print(f"Modus: {mode_value}")
    return mode_value

# Panggil fungsi calc_modus untuk kedua dataset
modus_A = calc_modus(penjualan_A)
modus_B = calc_modus(penjualan_B)

# Visualisasi Data dengan Mean, Median, dan Modus
plt.figure(figsize=(12, 6))

# Plot distribusi Penjualan A dengan garis Mean, Median, dan Modus
plt.subplot(1, 2, 1)  # 1 baris, 2 kolom, plot 1
plt.hist(penjualan_A, bins=10, color='blue', alpha=0.7)
plt.axvline(mean_A, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {mean_A:.2f}')
plt.axvline(median_A, color='green', linestyle='dotted', linewidth=1, label=f'Median: {median_A:.2f}')
for mode in modus_A:
    plt.axvline(mode, color='purple', linestyle='solid', linewidth=1, label=f'Modus: {mode}')
plt.title('Distribusi Penjualan A')
plt.xlabel('Penjualan A (pcs)')
plt.ylabel('Frekuensi')
plt.legend()

# Plot distribusi Penjualan B dengan garis Mean, Median, dan Modus
plt.subplot(1, 2, 2)  # 1 baris, 2 kolom, plot 2
plt.hist(penjualan_B, bins=10, color='green', alpha=0.7)
plt.axvline(mean_B, color='red', linestyle='dashed', linewidth=1, label=f'Mean: {mean_B:.2f}')
plt.axvline(median_B, color='green', linestyle='dotted', linewidth=1, label=f'Median: {median_B:.2f}')
for mode in modus_B:
    plt.axvline(mode, color='purple', linestyle='solid', linewidth=1, label=f'Modus: {mode}')
plt.title('Distribusi Penjualan B')
plt.xlabel('Penjualan B (pcs)')
plt.ylabel('Frekuensi')
plt.legend()

# Tampilkan visualisasi
plt.tight_layout()
plt.show()
# Out:
# Modus: [0]
# Modus: [0]

# %%
import matplotlib.pyplot as plt  # untuk visualisasi data

# Fungsi untuk menghitung range
def calc_range(data):
    nilai_tertinggi = max(data)
    nilai_terendah = min(data)
    data_range = nilai_tertinggi - nilai_terendah
    print(f"Range: {nilai_tertinggi} - {nilai_terendah} = {data_range}")
    return data_range

# Fungsi visualisasi untuk dua dataset
def visualize_range(penjualan_A, penjualan_B):
    # Membuat histogram untuk Penjualan A dan Penjualan B
    plt.hist(penjualan_A, bins=30, edgecolor='black', alpha=0.5, color='green', label='Penjualan A')
    plt.hist(penjualan_B, bins=30, edgecolor='black', alpha=0.5, color='orange', label='Penjualan B')

    # Menghitung range Penjualan A dan B
    calc_range(penjualan_A)
    calc_range(penjualan_B)

    # Menambahkan garis vertikal untuk nilai min dan max dari Penjualan A
    plt.axvline(x=min(penjualan_A), color='blue', linestyle='dashed', linewidth=1, label=f'Min A: {min(penjualan_A):.2f}')
    plt.axvline(x=max(penjualan_A), color='blue', linestyle='dashed', linewidth=1, label=f'Max A: {max(penjualan_A):.2f}')

    # Menambahkan garis vertikal untuk nilai min dan max dari Penjualan B
    plt.axvline(x=min(penjualan_B), color='red', linestyle='dashed', linewidth=1, label=f'Min B: {min(penjualan_B):.2f}')
    plt.axvline(x=max(penjualan_B), color='red', linestyle='dashed', linewidth=1, label=f'Max B: {max(penjualan_B):.2f}')

    # Menambahkan label, judul, dan legenda
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title('Range Penjualan A dan B')
    plt.legend()

    # Menampilkan plot
    plt.show()

# Contoh data penjualan
penjualan_A = dataset['Penjualan A (pcs)']
penjualan_B = dataset['Penjualan B (pcs)']

# Memanggil visualisasi
visualize_range(penjualan_A, penjualan_B)
# Out:
# Range: 458 - 0 = 458
# Range: 545 - 0 = 545

# %%
def calc_mean(penjualan_A):
    # Menghitung rata-rata
    return sum(penjualan_A) / len(penjualan_A)

def calc_variance(penjualan_A):
    mean = calc_mean(penjualan_A)
    
    # Kuadrat selisih antara setiap nilai data dengan rata-rata
    squared_diff = []
    for x in penjualan_A:
        squared_diff_per_x = (x - mean) ** 2
        squared_diff.append(squared_diff_per_x)
    
    # Jumlah kuadrat selisih antara setiap nilai data dengan rata-rata, kemudian dibagi dengan jumlah total data
    variance = sum(squared_diff) / len(penjualan_A)
    
    print(f"Variansi Penjualan A: {sum(squared_diff)} / {len(penjualan_A)} = {variance}")
    return variance

# Asumsikan dataset sudah terdefinisi sebelumnya
penjualan_B = dataset['Penjualan A (pcs)']
calc_variance(penjualan_A)
# Out:
# Variansi Penjualan A: 2405960.694214876 / 121 = 19883.97267946178
# 19883.97267946178

# %%
def calc_variance_penjualan_B(penjualan_B):
    mean = calc_mean(penjualan_B)
    
    # Kuadrat selisih antara setiap nilai data dengan rata-rata
    squared_diff = []
    for x in penjualan_B:
        squared_diff_per_x = (x - mean) ** 2
        squared_diff.append(squared_diff_per_x)
    
    # Jumlah kuadrat selisih antara setiap nilai data dengan rata-rata, kemudian dibagi dengan jumlah total data
    variance = sum(squared_diff) / len(penjualan_B)
    
    print(f"Variansi Penjualan B: {sum(squared_diff)} / {len(penjualan_B)} = {variance}")
    return variance

# Asumsikan dataset sudah terdefinisi sebelumnya
penjualan_B = dataset['Penjualan B (pcs)']
calc_variance_penjualan_B(penjualan_B)
# Out:
# Variansi Penjualan B: 3075270.0 / 121 = 25415.454545454544
# 25415.454545454544

# %%
import matplotlib.pyplot as plt

std_penjualan_A = dataset['Penjualan A (pcs)'].std()
std_penjualan_B = dataset['Penjualan B (pcs)'].std()

def visualize_std(penjualan, title, mean, std_dev):
    plt.hist(penjualan, bins=30, edgecolor='black', alpha=0.5, color='green')

    # Tambahkan garis vertikal pada mean dan standar deviasi
    plt.axvline(x=mean, color='red', linestyle='dashed', linewidth=1, label=f'Mean = {mean:.2f}')
    plt.axvline(x=mean - std_dev, color='blue', linestyle='dashed', linewidth=1, label=f'{mean - std_dev:.2f}')
    plt.axvline(x=mean + std_dev, color='blue', linestyle='dashed', linewidth=1, label=f'{mean + std_dev:.2f}')

    # Tambahkan label dan judul
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title(f'{title} (Std Dev = {std_dev:.2f})')

    # Tambahkan legenda
    plt.legend()

    # Tampilkan plot
    plt.show()

# Calculate mean for Penjualan A and Penjualan B
mean_penjualan_A = dataset['Penjualan A (pcs)'].mean()
mean_penjualan_B = dataset['Penjualan B (pcs)'].mean()

# Visualize Penjualan A
visualize_std(dataset['Penjualan A (pcs)'], 'Penjualan A', mean_penjualan_A, std_penjualan_A)

# Visualize Penjualan B
visualize_std(dataset['Penjualan B (pcs)'], 'Penjualan B', mean_penjualan_B, std_penjualan_B)

# %%
# Mengonversi kolom menjadi tipe numerik
penjualan_B = pd.to_numeric(dataset['Penjualan A (pcs)'], errors='coerce')
penjualan_B = pd.to_numeric(dataset['Penjualan B (pcs)'], errors='coerce')

# Menghitung jangkauan interkuartil (IQR) untuk setiap kolom
def hitung_iqr(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    return IQR

iqr_A = hitung_iqr(penjualan_B)
iqr_B = hitung_iqr(penjualan_B)

print(f'Jangkauan Interkuartil (IQR) untuk Penjualan A: {iqr_A}')
print(f'Jangkauan Interkuartil (IQR) untuk Penjualan B: {iqr_B}')

import matplotlib.pyplot as plt
import numpy as np

# Membuat Tabel Distribusi Frekuensi
def buat_tabel_frekuensi(data, bins):
    # Menghitung frekuensi untuk setiap interval
    frekuensi, batas = np.histogram(data, bins=bins)
    tabel = pd.DataFrame({
        'Interval': [f'{batas[i]:.2f} - {batas[i+1]:.2f}' for i in range(len(batas)-1)],
        'Frekuensi': frekuensi
    })
    return tabel, batas

# Menentukan jumlah kelas (bins) untuk histogram
bins = 10

# Membuat tabel distribusi frekuensi untuk Penjualan A dan B
tabel_frekuensi_A, batas_A = buat_tabel_frekuensi(penjualan_B, bins)
tabel_frekuensi_B, batas_B = buat_tabel_frekuensi(penjualan_B, bins)

print("Tabel Distribusi Frekuensi Penjualan A:")
print(tabel_frekuensi_A)
print("\nTabel Distribusi Frekuensi Penjualan B:")
print(tabel_frekuensi_B)

# Visualisasi Histogram dan Poligon Frekuensi
plt.figure(figsize=(14, 7))

# Histogram untuk Penjualan A
plt.subplot(1, 2, 1)
plt.hist(penjualan_B, bins=bins, alpha=0.7, color='blue', edgecolor='black')
plt.title('Histogram Penjualan A')
plt.xlabel('Jumlah Penjualan (pcs)')
plt.ylabel('Frekuensi')

# Poligon Frekuensi untuk Penjualan A
titik_tengah_A = [(batas_A[i] + batas_A[i+1]) / 2 for i in range(len(batas_A)-1)]
plt.plot(titik_tengah_A, tabel_frekuensi_A['Frekuensi'], marker='o', color='blue', label='Poligon Frekuensi A')
plt.legend()

# Histogram untuk Penjualan B
plt.subplot(1, 2, 2)
plt.hist(penjualan_B, bins=bins, alpha=0.7, color='green', edgecolor='black')
plt.title('Histogram Penjualan B')
plt.xlabel('Jumlah Penjualan (pcs)')
plt.ylabel('Frekuensi')

# Poligon Frekuensi untuk Penjualan B
titik_tengah_B = [(batas_B[i] + batas_B[i+1]) / 2 for i in range(len(batas_B)-1)]
plt.plot(titik_tengah_B, tabel_frekuensi_B['Frekuensi'], marker='o', color='green', label='Poligon Frekuensi B')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Jangkauan Interkuartil (IQR) untuk Penjualan A: 244.0
# Jangkauan Interkuartil (IQR) untuk Penjualan B: 244.0
# Tabel Distribusi Frekuensi Penjualan A:
#           Interval  Frekuensi
# 0     0.00 - 54.50         25
# 1   54.50 - 109.00         13
# 2  109.00 - 163.50         24
# 3  163.50 - 218.00         10
# 4  218.00 - 272.50         11
# 5  272.50 - 327.00          8
# 6  327.00 - 381.50          7
# 7  381.50 - 436.00          9
# 8  436.00 - 490.50          7
# 9  490.50 - 545.00          7
#
# Tabel Distribusi Frekuensi Penjualan B:
#           Interval  Frekuensi
# 0     0.00 - 54.50         25
# 1   54.50 - 109.00         13
# 2  109.00 - 163.50         24
# 3  163.50 - 218.00         10
# 4  218.00 - 272.50         11
# 5  272.50 - 327.00          8
# 6  327.00 - 381.50          7
# 7  381.50 - 436.00          9
# 8  436.00 - 490.50          7
# 9  490.50 - 545.00          7

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Visualisasi menggunakan Boxplot
plt.figure(figsize=(12, 6))

# Boxplot untuk Penjualan A
plt.subplot(1, 2, 1)
sns.boxplot(x=penjualan_A, color='lightblue')
plt.title('Boxplot Penjualan A')

# Boxplot untuk Penjualan B
plt.subplot(1, 2, 2)
sns.boxplot(x=penjualan_B, color='lightgreen')
plt.title('Boxplot Penjualan B')

plt.tight_layout()
plt.show()

# Perhitungan IQR untuk mendeteksi outlier pada Penjualan A
Q1_A = np.percentile(penjualan_A, 25)
Q3_A = np.percentile(penjualan_A, 75)
IQR_A = Q3_A - Q1_A
lower_bound_A = Q1_A - 1.5 * IQR_A
upper_bound_A = Q3_A + 1.5 * IQR_A
outliers_A = [x for x in penjualan_A if x < lower_bound_A or x > upper_bound_A]

# Perhitungan IQR untuk mendeteksi outlier pada Penjualan B
Q1_B = np.percentile(penjualan_B, 25)
Q3_B = np.percentile(penjualan_B, 75)
IQR_B = Q3_B - Q1_B
lower_bound_B = Q1_B - 1.5 * IQR_B
upper_bound_B = Q3_B + 1.5 * IQR_B
outliers_B = [x for x in penjualan_B if x < lower_bound_B or x > upper_bound_B]

# Tampilkan hasil outlier
print(f"Outliers in Penjualan A: {outliers_A}")
print(f"Outliers in Penjualan B: {outliers_B}")
# Out:
# Outliers in Penjualan A: []
# Outliers in Penjualan B: []

# %%
#

# %%
import pandas as pd
from scipy.stats import skew, mode
import numpy as np

# Contoh data (gunakan dataset yang sesuai)
penjualan_A = pd.to_numeric(dataset['Penjualan A (pcs)'], errors='coerce')
penjualan_B = pd.to_numeric(dataset['Penjualan B (pcs)'], errors='coerce')

# Menghitung mean, median, dan modus untuk Penjualan A
mean_A = penjualan_A.mean()
median_A = penjualan_A.median()
# Memastikan hasil mode diakses dengan benar
modus_A_result = mode(penjualan_A.dropna(), nan_policy='omit')
modus_A = modus_A_result.mode[0] if isinstance(modus_A_result.mode, np.ndarray) and len(modus_A_result.mode) > 0 else modus_A_result.mode

# Menghitung mean, median, dan modus untuk Penjualan B
mean_B = penjualan_B.mean()
median_B = penjualan_B.median()
modus_B_result = mode(penjualan_B.dropna(), nan_policy='omit')
modus_B = modus_B_result.mode[0] if isinstance(modus_B_result.mode, np.ndarray) and len(modus_B_result.mode) > 0 else modus_B_result.mode

# Menghitung skewness untuk Penjualan A dan B
skewness_A = skew(penjualan_A.dropna())
skewness_B = skew(penjualan_B.dropna())

# Menampilkan hasil
print(f"Penjualan A - Mean: {mean_A:.2f}, Median: {median_A:.2f}, Modus: {modus_A}")
print(f"Penjualan A - Skewness: {skewness_A:.2f}")
print(f"Penjualan B - Mean: {mean_B:.2f}, Median: {median_B:.2f}, Modus: {modus_B}")
print(f"Penjualan B - Skewness: {skewness_B:.2f}")

import matplotlib.pyplot as plt
import seaborn as sns

# Visualisasi histogram dengan informasi skewness, mean, median, dan modus untuk Penjualan A dan B
plt.figure(figsize=(12, 6))

# Histogram untuk Penjualan A
plt.subplot(1, 2, 1)
sns.histplot(penjualan_A.dropna(), bins=30, kde=True, color='blue')
plt.axvline(mean_A, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean_A:.2f}')
plt.axvline(median_A, color='green', linestyle='dotted', linewidth=2, label=f'Median: {median_A:.2f}')
if modus_A is not None:
    plt.axvline(modus_A, color='purple', linestyle='dashdot', linewidth=2, label=f'Modus: {modus_A}')
plt.title(f'Skewness Penjualan A: {skewness_A:.2f}')
plt.xlabel('Penjualan A (pcs)')
plt.ylabel('Frekuensi')
plt.legend()

# Histogram untuk Penjualan B
plt.subplot(1, 2, 2)
sns.histplot(penjualan_B.dropna(), bins=30, kde=True, color='green')
plt.axvline(mean_B, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean_B:.2f}')
plt.axvline(median_B, color='green', linestyle='dotted', linewidth=2, label=f'Median: {median_B:.2f}')
if modus_B is not None:
    plt.axvline(modus_B, color='purple', linestyle='dashdot', linewidth=2, label=f'Modus: {modus_B}')
plt.title(f'Skewness Penjualan B: {skewness_B:.2f}')
plt.xlabel('Penjualan B (pcs)')
plt.ylabel('Frekuensi')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Penjualan A - Mean: 131.83, Median: 52.00, Modus: 0
# Penjualan A - Skewness: 0.70
# Penjualan B - Mean: 205.55, Median: 157.00, Modus: 0
# Penjualan B - Skewness: 0.59

# %%
#PERHITUNGAN FAQIH
import pandas as pd
from scipy.stats import kurtosis

# Membaca file Excel
dataset = pd.read_excel("Dataset.xlsx")

# Mengonversi kolom Penjualan A dan Penjualan B menjadi numerik
penjualan_A = pd.to_numeric(dataset['Penjualan A (pcs)'], errors='coerce')
penjualan_B = pd.to_numeric(dataset['Penjualan B (pcs)'], errors='coerce')

# Menghitung kurtosis untuk Penjualan A dan Penjualan B
kurtosis_A = kurtosis(penjualan_A, nan_policy='omit')
kurtosis_B = kurtosis(penjualan_B, nan_policy='omit')

# Menampilkan hasil
print(f'Kurtosis Penjualan A: {kurtosis_A}')
print(f'Kurtosis Penjualan B: {kurtosis_B}')

#VISUALISASI FAQIH
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm, kurtosis

# Membaca file Excel
dataset = pd.read_excel("Dataset.xlsx")

# Mengonversi kolom Penjualan A dan Penjualan B menjadi numerik
penjualan_A = pd.to_numeric(dataset['Penjualan A (pcs)'], errors='coerce')
penjualan_B = pd.to_numeric(dataset['Penjualan B (pcs)'], errors='coerce')

# Menghitung kurtosis untuk Penjualan A dan Penjualan B
kurtosis_A = kurtosis(penjualan_A, nan_policy='omit')
kurtosis_B = kurtosis(penjualan_B, nan_policy='omit')

# Visualisasi Penjualan A
plt.figure(figsize=(12, 6))

# Plot histogram dan fit kurva normal untuk Penjualan A
plt.subplot(1, 2, 1)
sns.histplot(penjualan_A, kde=False, color='blue', stat='density')
mu_A, std_A = penjualan_A.mean(), penjualan_A.std()
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu_A, std_A)
plt.plot(x, p, 'k', linewidth=2)
title_A = f'Penjualan A\nKurtosis: {kurtosis_A:.2f}'
plt.title(title_A)
plt.xlabel('Penjualan A (pcs)')
plt.ylabel('Density')

# Visualisasi Penjualan B
# Plot histogram dan fit kurva normal untuk Penjualan B
plt.subplot(1, 2, 2)
sns.histplot(penjualan_B, kde=False, color='green', stat='density')
mu_B, std_B = penjualan_B.mean(), penjualan_B.std()
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu_B, std_B)
plt.plot(x, p, 'k', linewidth=2)
title_B = f'Penjualan B\nKurtosis: {kurtosis_B:.2f}'
plt.title(title_B)
plt.xlabel('Penjualan B (pcs)')
plt.ylabel('Density')

# Menampilkan plot
plt.tight_layout()
plt.show()
# Out:
# Kurtosis Penjualan A: -0.8702898002535826
# Kurtosis Penjualan B: -0.8313825467735128

# %%
import pandas as pd
from scipy.stats import kurtosis

# Membaca file Excel
dataset = pd.read_excel("Dataset.xlsx")

# Mengonversi kolom Penjualan A dan Penjualan B menjadi numerik
penjualan_A = pd.to_numeric(dataset['Penjualan A (pcs)'], errors='coerce')
penjualan_B = pd.to_numeric(dataset['Penjualan B (pcs)'], errors='coerce')

# Menghilangkan nilai NaN
penjualan_A = penjualan_A.dropna()
penjualan_B = penjualan_B.dropna()

# Menghitung Q1, Q3, dan IQR
Q1_A = penjualan_A.quantile(0.25)
Q3_A = penjualan_A.quantile(0.75)
IQR_A = Q3_A - Q1_A

Q1_B = penjualan_B.quantile(0.25)
Q3_B = penjualan_B.quantile(0.75)
IQR_B = Q3_B - Q1_B

# Menghitung batas bawah dan atas
batas_bawah_A = Q1_A - 1.5 * IQR_A
batas_atas_A = Q3_A + 1.5 * IQR_A

batas_bawah_B = Q1_B - 1.5 * IQR_B
batas_atas_B = Q3_B + 1.5 * IQR_B

# Menampilkan batas atas dan bawah untuk verifikasi
print(f"Batas bawah Penjualan A: {batas_bawah_A}, Batas atas Penjualan A: {batas_atas_A}")
print(f"Batas bawah Penjualan B: {batas_bawah_B}, Batas atas Penjualan B: {batas_atas_B}")

# Mencari outlier
outlier_A = penjualan_A[(penjualan_A < batas_bawah_A) | (penjualan_A > batas_atas_A)]
outlier_B = penjualan_B[(penjualan_B < batas_bawah_B) | (penjualan_B > batas_atas_B)]

# Menampilkan outlier dengan penanganan jika tidak ada outlier
if not outlier_A.empty:
    print("Outlier Penjualan A (pcs):")
    print(outlier_A)
else:
    print("Tidak ada outlier di Penjualan A.")

if not outlier_B.empty:
    print("Outlier Penjualan B (pcs):")
    print(outlier_B)
else:
    print("Tidak ada outlier di Penjualan B.")
# Out:
# Batas bawah Penjualan A: -344.5, Batas atas Penjualan A: 587.5
# Batas bawah Penjualan B: -286.0, Batas atas Penjualan B: 690.0
# Tidak ada outlier di Penjualan A.
# Tidak ada outlier di Penjualan B.

# %% [markdown]
# 1. Jelaskan apa fungsi dari boxplot
# •	Boxplot dapat mengidentifikasi rentang data: box plot menunjukkan rentang antara nilai minimum dan maksimum dalam suatu set data, memberikan pemahaman cepat tentang seberapa luas data tersebut tersebar.
# •	Boxplot dapat memvisualisasikan kuartil: box plot membagi data menjadi empat bagian (kuartil), sehingga memudahkan untuk melihat median (kuartil kedua) dan membandingkan kuartil pertama dan ketiga. Hal ini membantu dalam memahami seberapa terpusat atau tersebar data tersebut.
# •	Boxplot dapat mendeteksi outlier: dengan 'whiskers' atau garis yang membentang dari kotak, box plot menunjukkan variasi di luar kuartil atas dan bawah. Data yang berada di luar whiskers sering dianggap sebagai outlier, memberikan indikasi tentang adanya nilai yang sangat berbeda dari keseluruhan data.
# •	Boxplot dapat membandingkan distribusi: box plot juga berguna untuk membandingkan distribusi antara beberapa kelompok atau kategori. Hal ini memudahkan dalam melihat perbedaan median, rentang, dan variasi antara kelompok-kelompok tersebut.

# %% [markdown]
# 2. Jelaskan perbedaan boxplot dengan histogram
# Perbedaan utama antara boxplot dan histogram adalah fungsi dan cara penggunaan masing-masing:
# (pengertian)
# •	Histogram adalah representasi grafis data yang disajikan dalam bentuk diagram batang, yang menunjukkan frekuensi atau seberapa sering suatu hasil terjadi dalam kumpulan data. Boxplot
# •	Boxplot merupakan ringkasan distribusi sampel yang disajikan secara grafis yang bisa menggambarkan bentuk distribusi data (skewness), ukuran tendensi sentral dan ukuran penyebaran (keragaman) data pengamatan.
#
#     Berikut beberapa perbedaan lainnya antara boxplot dan histogram:
# •	Boxplot memerlukan ukuran sampel yang lebih kecil, yaitu 5, sedangkan histogram memerlukan ukuran sampel minimal 30.
# •	Boxplot lebih baik dalam membandingkan distribusi antara beberapa kelompok atau set data.
# •	Boxplot tidak ideal untuk menggambarkan respons rata-rata atau penyebaran data.
# •	Meringkas data dengan boxplot dapat menjadi jebakan karena kita kehilangan informasi, seperti distribusi titik-titik yang mendasarinya di setiap kelompok atau jumlah pengamatannya.

# %% [markdown]
# Dari hasil analisis kami, kami mendapatkan data modus, mean, median, kurtosis, skewness, range, varian, IQR, standar deviasi, semua beserta
# visualisasinya. Modus penjualan A dan B adalah 0. Mean penjualan A adalah 131.83 dan mean penjualan B adalah 205.55. Kurtosis penjualan A
# adalah -0.87 dan kurtosis penjualan B adalah -0.83. Skewness penjualan A adalah 0.70 dan skewness penjualan B adalah 0.59. Range penjualan
# A adalah 458 dan range penjualan B adalah 545. Varian penjualan A adalah 19883 dan varian penjualan B adalah 25415. IQR penjualan A dan B adalah 244.
# standar deviasi penjualan A adalah 141.60 dan standar deviasi penjualan B adalah 160.09. Dari data tersebut, kami tidak menemukan adanya
# outlier ekstrim maupun minor.
